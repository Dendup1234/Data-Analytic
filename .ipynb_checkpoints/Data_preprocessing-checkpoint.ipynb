# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd

# %%
df = pd.read_csv("EPL.csv")

# %%
df
# Out:
#                        League        Date       HomeTeam      AwayTeam  \
# 0      English Premier League    16/08/08        Arsenal     West Brom
# 1      English Premier League    16/08/08         Bolton         Stoke
# 2      English Premier League    16/08/08        Everton     Blackburn
# 3      English Premier League    16/08/08           Hull        Fulham
# 4      English Premier League    16/08/08  Middlesbrough     Tottenham
# ...                       ...         ...            ...           ...
# 12785  English Premier League  12/05/2019      Liverpool        Wolves
# 12786  English Premier League  12/05/2019     Man United       Cardiff
# 12787  English Premier League  12/05/2019    Southampton  Huddersfield
# 12788  English Premier League  12/05/2019      Tottenham       Everton
# 12789  English Premier League  12/05/2019        Watford      West Ham
#
#        HomeGoals  AwayGoals Result
# 0            1.0        0.0      H
# 1            3.0        1.0      H
# 2            2.0        3.0      A
# 3            2.0        1.0      H
# 4            2.0        1.0      H
# ...          ...        ...    ...
# 12785        2.0        0.0      H
# 12786        0.0        2.0      A
# 12787        1.0        1.0      D
# 12788        2.0        2.0      D
# 12789        1.0        4.0      A
#
# [12790 rows x 7 columns]

# %%
df.head()
# Out:
#                    League      Date       HomeTeam   AwayTeam  HomeGoals  \
# 0  English Premier League  16/08/08        Arsenal  West Brom        1.0
# 1  English Premier League  16/08/08         Bolton      Stoke        3.0
# 2  English Premier League  16/08/08        Everton  Blackburn        2.0
# 3  English Premier League  16/08/08           Hull     Fulham        2.0
# 4  English Premier League  16/08/08  Middlesbrough  Tottenham        2.0
#
#    AwayGoals Result
# 0        0.0      H
# 1        1.0      H
# 2        3.0      A
# 3        1.0      H
# 4        1.0      H

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12790 entries, 0 to 12789
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   League     12790 non-null  object
#  1   Date       12093 non-null  object
#  2   HomeTeam   12093 non-null  object
#  3   AwayTeam   12093 non-null  object
#  4   HomeGoals  12093 non-null  float64
#  5   AwayGoals  12093 non-null  float64
#  6   Result     12093 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 699.6+ KB

# %%
# Doing the label encoding here for the score calculation
df['Result'] = df['Result'].map({'H':1,'D':0,'A':-1})

# %%
df
# Out:
#                        League        Date       HomeTeam      AwayTeam  \
# 0      English Premier League    16/08/08        Arsenal     West Brom
# 1      English Premier League    16/08/08         Bolton         Stoke
# 2      English Premier League    16/08/08        Everton     Blackburn
# 3      English Premier League    16/08/08           Hull        Fulham
# 4      English Premier League    16/08/08  Middlesbrough     Tottenham
# ...                       ...         ...            ...           ...
# 12785  English Premier League  12/05/2019      Liverpool        Wolves
# 12786  English Premier League  12/05/2019     Man United       Cardiff
# 12787  English Premier League  12/05/2019    Southampton  Huddersfield
# 12788  English Premier League  12/05/2019      Tottenham       Everton
# 12789  English Premier League  12/05/2019        Watford      West Ham
#
#        HomeGoals  AwayGoals  Result
# 0            1.0        0.0     1.0
# 1            3.0        1.0     1.0
# 2            2.0        3.0    -1.0
# 3            2.0        1.0     1.0
# 4            2.0        1.0     1.0
# ...          ...        ...     ...
# 12785        2.0        0.0     1.0
# 12786        0.0        2.0    -1.0
# 12787        1.0        1.0     0.0
# 12788        2.0        2.0     0.0
# 12789        1.0        4.0    -1.0
#
# [12790 rows x 7 columns]

# %%
# Dropping the unnecessary feature from the csv file
df.drop(columns=['League'],inplace= True)

# %%
df
# Out:
#              Date       HomeTeam      AwayTeam  HomeGoals  AwayGoals  Result
# 0        16/08/08        Arsenal     West Brom        1.0        0.0     1.0
# 1        16/08/08         Bolton         Stoke        3.0        1.0     1.0
# 2        16/08/08        Everton     Blackburn        2.0        3.0    -1.0
# 3        16/08/08           Hull        Fulham        2.0        1.0     1.0
# 4        16/08/08  Middlesbrough     Tottenham        2.0        1.0     1.0
# ...           ...            ...           ...        ...        ...     ...
# 12785  12/05/2019      Liverpool        Wolves        2.0        0.0     1.0
# 12786  12/05/2019     Man United       Cardiff        0.0        2.0    -1.0
# 12787  12/05/2019    Southampton  Huddersfield        1.0        1.0     0.0
# 12788  12/05/2019      Tottenham       Everton        2.0        2.0     0.0
# 12789  12/05/2019        Watford      West Ham        1.0        4.0    -1.0
#
# [12790 rows x 6 columns]

# %%
# For the date segregation

# %%
teams = df['HomeTeam'].unique()

# %%
len(teams)
# Out:
# 52

# %%
teams
# Out:
# array(['Arsenal', 'Bolton', 'Everton', 'Hull', 'Middlesbrough',
#        'Sunderland', 'West Ham', 'Aston Villa', 'Chelsea', 'Man United',
#        'Blackburn', 'Fulham', 'Liverpool', 'Newcastle', 'Stoke',
#        'Tottenham', 'West Brom', 'Man City', 'Wigan', 'Portsmouth',
#        'Wolves', 'Birmingham', 'Blackpool', 'Brentford', 'Burnley',
#        'Leicester', 'Watford', 'Norwich', 'Crystal Palace', 'Leeds',
#        'Brighton', 'Southampton', 'QPR', 'Swansea', nan, 'Bournemouth',
#        'Sheffield United', 'Charlton', 'Coventry', 'Derby', 'Bradford',
#        'Ipswich', 'Sheffield Weds', 'Wimbledon', "Nott'm Forest",
#        'Huddersfield', 'Reading', 'Barnsley', 'Cardiff', 'Luton',
#        'Oldham', 'Swindon'], dtype=object)
